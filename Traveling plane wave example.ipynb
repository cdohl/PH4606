# %%
# %matplotlib inline
import math as m
import numpy #array operations
import matplotlib.pyplot as plt #plotting

# %%
x=numpy.arange(0.,3.,.01)
t0=0.
t1=.1
k=2.*m.pi/1.
plt.plot(x,numpy.cos(2.*m.pi*t0-k*x))
plt.plot(x,numpy.cos(2.*m.pi*t1-k*x),'.');
